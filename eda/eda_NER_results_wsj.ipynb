# %%
import pandas as pd
import os

# %%
# inputs
main_dir = "wsj"
ner_mapped = "mapped_gemma"
parent_dir = os.path.dirname(os.getcwd())

# %%
df_1 = pd.DataFrame()
for filename in os.listdir(os.path.join(main_dir, ner_mapped)):

    df_new = pd.read_csv(os.path.join(main_dir, ner_mapped, filename))
    df_new = df_new.loc[pd.notnull(df_new['Company_name_mapped'])]
    df_1  = pd.concat([df_1, df_new], axis=0)

df_1 ['u3_num'] = df_1 ['u3_num'].astype(int).astype(str)

# %%
# EDA on the video data collected from the channel
df_3 = pd.read_csv(os.path.join(parent_dir, "channel_scraper", f"{main_dir}_DB.csv"))
df_3['date_published'] = pd.to_datetime(df_3['date_published'], format='%Y-%m-%dT%H:%M:%SZ') 
print(f"Total videos: {len(df_3)}")
df_3.groupby(df_3.date_published.dt.year)['vid_id'].count()
# Out:
# Total videos: 24199
# date_published
# 2008     450
# 2009      62
# 2011     189
# 2012    4923
# 2013    3670
# 2014    3520
# 2015    3654
# 2016    4113
# 2017    1701
# 2018     304
# 2019     224
# 2020     281
# 2021     278
# 2022     331
# 2023     412
# 2024      87
# Name: vid_id, dtype: int64

# %%
df_1
# Out:
#          vid_id                  company_found_gemma  \
# 0   eKQ0sCgcsIc       Alcoa (Aluminum manufacturing)
# 1   eKQ0sCgcsIc    US companies (Various industries)
# 3   eKQ0sCgcsIc  HP (Computer hardware and software)
# 4   eKQ0sCgcsIc                    eBay (E-commerce)
# 5   eKQ0sCgcsIc          PayPal (Financial services)
# ..          ...                                  ...
# 14  4BRR9dcV0NE          Patron (Spirits & Liqueurs)
# 16  4BRR9dcV0NE     Roller Mill (Spirits & Liqueurs)
# 18  IuxKKvuG_94                     Porton ( Brandy)
# 21  u6-7M5fxPvQ                          wsj (Media)
# 23  u6-7M5fxPvQ                        OMC (Fashion)
#
#                           Company_name_mapped  u3_num
# 0                                  Alcoa Corp  194737
# 1                         US 1 Industries Inc   28230
# 3                                      HP Inc   27582
# 4                                    eBay Inc   44584
# 5                                  PayPal Inc   36173
# ..                                        ...     ...
# 14                         Patron Systems Inc   44971
# 16  Kovilpatti Lakshmi Roller Flour Mills Ltd   14722
# 18                Porton Pharma Solutions Ltd  164014
# 21                          WJ Communications   36772
# 23                              I/Omagic Corp   40304
#
# [25079 rows x 4 columns]

# %%
df_1.loc[df_1['company_found_gemma'].str.contains("American A")]
# Out:
#          vid_id          company_found_gemma          Company_name_mapped  \
# 4   422kBOP-EAo  American Airlines - Airline  American Airlines Group Inc
# 61  mU1csl3R9eU  American Airlines (Airline)  American Airlines Group Inc
# 25  iPxthIFlGco  American Airlines (Airline)  American Airlines Group Inc
# 5   635iZPETnEo  American Airlines (Airline)  American Airlines Group Inc
# 4   d0VNeGiZjoI  American Airlines (Airline)  American Airlines Group Inc
# ..          ...                          ...                          ...
# 5   PUr1fekPcBg  American Airlines (Airline)  American Airlines Group Inc
# 12  ZWEwgsKb690  American Airlines (Airline)  American Airlines Group Inc
# 5   qFWkLLOXoIQ  American Airlines - Airline  American Airlines Group Inc
# 23  d8NsqRyl-n4  American Airlines (Airline)  American Airlines Group Inc
# 15  XOxZtFWevLw  American Airlines - Airline  American Airlines Group Inc
#
#    u3_num
# 4   27053
# 61  27053
# 25  27053
# 5   27053
# 4   27053
# ..    ...
# 5   27053
# 12  27053
# 5   27053
# 23  27053
# 15  27053
#
# [61 rows x 4 columns]

# %%
df_1.loc[df_1['Company_name_mapped'].str.contains("American A")]
# Out:
#          vid_id          company_found_gemma          Company_name_mapped  \
# 4   422kBOP-EAo  American Airlines - Airline  American Airlines Group Inc
# 61  mU1csl3R9eU  American Airlines (Airline)  American Airlines Group Inc
# 25  iPxthIFlGco  American Airlines (Airline)  American Airlines Group Inc
# 5   635iZPETnEo  American Airlines (Airline)  American Airlines Group Inc
# 4   d0VNeGiZjoI  American Airlines (Airline)  American Airlines Group Inc
# ..          ...                          ...                          ...
# 5   PUr1fekPcBg  American Airlines (Airline)  American Airlines Group Inc
# 12  ZWEwgsKb690  American Airlines (Airline)  American Airlines Group Inc
# 5   qFWkLLOXoIQ  American Airlines - Airline  American Airlines Group Inc
# 23  d8NsqRyl-n4  American Airlines (Airline)  American Airlines Group Inc
# 15  XOxZtFWevLw  American Airlines - Airline  American Airlines Group Inc
#
#    u3_num
# 4   27053
# 61  27053
# 25  27053
# 5   27053
# 4   27053
# ..    ...
# 5   27053
# 12  27053
# 5   27053
# 23  27053
# 15  27053
#
# [64 rows x 4 columns]

# %%
# Get top most mentioned companies

def compute_entity_frequency(df, top_k=35):
    values = df['Company_name_mapped'].value_counts().keys().tolist()
    counts = df['Company_name_mapped'].value_counts().tolist()

    for i, (value, count) in enumerate(zip(values, counts)):
        if i == top_k:
            break
        print(value, count)

compute_entity_frequency(df_1)
# Out:
# Apple Inc 849
# Wall Street Media Co Inc 824
# Wall Street Finance & Secs 683
# Google Inc 662
# Amazon.com Inc 405
# WJ Communications 361
# SOCIAL MEDIA GROUP 304
# Microsoft Corp 300
# Samsung Electronics Co Ltd 285
# Twitter Inc 203
# Netflix Inc 183
# Goldman Sachs Group Inc/The 138
# Ford Motor Co 132
# Walt Disney Co/The 126
# MarketWatch Inc 125
# News Communications & Media PLC 119
# General Motors Co 118
# Tesla Inc 116
# Walmart Inc 115
# Verizon Communications Inc 105
# Sony Group Corp 92
# Morgan Stanley 83
# McDonald's Corp 78
# NBC Internet Inc 77
# JP Morgan & Co Inc 75
# HBO & Co 74
# Uber Technologies Inc 72
# Wall Street Finance Ltd 71
# CBS Inc 68
# Target Corp 67
# Delta Air Lines Inc 67
# ABC Co Ltd 66
# Toyota Auto Body Co Ltd 65
# Chrysler Corp 64
# BMW Industries Ltd 62

# %%
# how many belonging to the 5 focal firms?

u3_ids = ['31689','27053', '27465', '34793', '204165']
#u3_ids = ['28390']
u3_ids = ['27053']
#names = ['SVB', 'AA', 'Ford', 'NYCB', 'Wework']

df_1.loc[df_1['u3_num'].isin(u3_ids)]
# Out:
#          vid_id          company_found_gemma          Company_name_mapped  \
# 4   422kBOP-EAo  American Airlines - Airline  American Airlines Group Inc
# 61  mU1csl3R9eU  American Airlines (Airline)  American Airlines Group Inc
# 25  iPxthIFlGco  American Airlines (Airline)  American Airlines Group Inc
# 5   635iZPETnEo  American Airlines (Airline)  American Airlines Group Inc
# 4   d0VNeGiZjoI  American Airlines (Airline)  American Airlines Group Inc
# ..          ...                          ...                          ...
# 5   PUr1fekPcBg  American Airlines (Airline)  American Airlines Group Inc
# 12  ZWEwgsKb690  American Airlines (Airline)  American Airlines Group Inc
# 5   qFWkLLOXoIQ  American Airlines - Airline  American Airlines Group Inc
# 23  d8NsqRyl-n4  American Airlines (Airline)  American Airlines Group Inc
# 15  XOxZtFWevLw  American Airlines - Airline  American Airlines Group Inc
#
#    u3_num
# 4   27053
# 61  27053
# 25  27053
# 5   27053
# 4   27053
# ..    ...
# 5   27053
# 12  27053
# 5   27053
# 23  27053
# 15  27053
#
# [62 rows x 4 columns]

# %%
# aggregate by month and plot frequency of mentions

def plot_frequency_of_mentions_year_month(company_name="American Airlines", frequency='Q', figsize=(30,10)):

    metadata_filename=f'{main_dir}_DB.csv'

    df_2 = df_1.loc[df_1['Company_name_mapped'].str.contains(company_name)]
    df_3 = pd.read_csv(os.path.join(parent_dir, "channel_scraper", metadata_filename))
    df_3['date_published'] = pd.to_datetime(df_3['date_published'])

    df_merged = pd.merge(left=df_2, right=df_3[['vid_id', 'title', 'date_published']], on='vid_id')
    df_aggr = df_merged[['date_published', 'vid_id']].set_index("date_published").resample(frequency).count()
    df_aggr = df_aggr.reset_index()
    df_aggr['year_month'] = df_aggr['date_published'].dt.strftime('%Y-%m')
    #return df_aggr
    df_aggr.plot(x='year_month', y='vid_id', kind='bar', figsize=figsize)

# %%
plot_frequency_of_mentions_year_month(company_name="Google", frequency='Q', figsize=(30,10))

# %%
plot_frequency_of_mentions_year_month(company_name="Amazon", frequency='Q', figsize=(30,10))

# %%
plot_frequency_of_mentions_year_month(company_name="Microsoft", frequency='Q', figsize=(30,10))

# %%
plot_frequency_of_mentions_year_month(company_name="Apple", frequency='Q', figsize=(30,10))
